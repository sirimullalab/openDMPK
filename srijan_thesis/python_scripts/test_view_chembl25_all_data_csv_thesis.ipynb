# %%
#######################################################################################
# Author: Srijan Verma                                                              #
# School of Pharmacy                                                                #
# Sirimulla Research Group [http://www.sirimullaresearchgroup.com/]                 #
# The University of Texas at El Paso, TX, USA                                       #
# Last modified: 19/12/2019                                                         #
# Copyright (c) 2019 Srijan Verma and Sirimulla Research Group, under MIT license   #
#######################################################################################

# %%
import mysql.connector
import json
import pandas as pd

# %%
USER = 'tcrd'
HOST = '129.108.3.163'
PASS = 'tcrd'
DB = 'chembl25'

conn = mysql.connector.connect (user=USER, password=PASS,
                               host=HOST,database=DB,buffered=True)
cursor = conn.cursor()

# %%
sql = "show tables"
df = pd.read_sql(sql, conn)

# %%
df = pd.read_sql_query(sql, conn)

# %%
df
# Out:
#                Tables_in_chembl25
# 0                     action_type
# 1                      activities
# 2             activity_properties
# 3                   activity_smid
# 4            activity_stds_lookup
# 5                   activity_supp
# 6               activity_supp_map
# 7                 assay_class_map
# 8            assay_classification
# 9                assay_parameters
# 10                     assay_type
# 11                         assays
# 12             atc_classification
# 13                  binding_sites
# 14        bio_component_sequences
# 15              bioassay_ontology
# 16      biotherapeutic_components
# 17                biotherapeutics
# 18                cell_dictionary
# 19               chembl_id_lookup
# 20                component_class
# 21              component_domains
# 22                   component_go
# 23            component_sequences
# 24             component_synonyms
# 25            compound_properties
# 26               compound_records
# 27     compound_structural_alerts
# 28            compound_structures
# 29        confidence_score_lookup
# ..                            ...
# 47    molecule_atc_classification
# 48            molecule_dictionary
# 49   molecule_frac_classification
# 50             molecule_hierarchy
# 51   molecule_hrac_classification
# 52   molecule_irac_classification
# 53              molecule_synonyms
# 54                 organism_class
# 55               patent_use_codes
# 56      predicted_binding_domains
# 57                product_patents
# 58                       products
# 59         protein_class_synonyms
# 60         protein_classification
# 61  protein_family_classification
# 62              relationship_type
# 63             research_companies
# 64                  research_stem
# 65                site_components
# 66                         source
# 67          structural_alert_sets
# 68              structural_alerts
# 69              target_components
# 70              target_dictionary
# 71               target_relations
# 72                    target_type
# 73              tissue_dictionary
# 74                     usan_stems
# 75              variant_sequences
# 76                        version
#
# [77 rows x 1 columns]

# %%
# %%time
dde = pd.read_csv('/home/exxact/Desktop/srijan_thesis/dataset/chembl25_data_in_csv/chembl25_all_data/activities.csv',low_memory=False, index_col=0)
# Out:
# CPU times: user 58.1 s, sys: 9.74 s, total: 1min 7s
# Wall time: 1min

# %%
df.head(2)
# Out:
#   Tables_in_chembl25
# 0        action_type
# 1         activities

# %%
len(dde)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-272d0f0a9717> in <module>
# ----> 1 len(dde)
#
# NameError: name 'dde' is not defined
